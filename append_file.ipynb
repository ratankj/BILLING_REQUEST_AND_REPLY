# %% [markdown]
# ## Apend all the R.R  file into one file

# %%
import os
import shutil
import pandas as pd

# %%
new_Dataframe = []

path = r"C:\Users\Ratan Kumar Jha\Desktop\BILLING_REQUEST_AND_REPLY\Billing_request\output_request\AUG_DATA_NEW"
for file in os.listdir(path):
    print(file)
    if file.endswith(".csv"):
        new_file_path = os.path.join(path,file)
        data = pd.read_csv(new_file_path)
        
        new_Dataframe.append(data)

    
# Concatenate all the DataFrames in the list into a single DataFrame
final_dataframe = pd.concat(new_Dataframe, ignore_index=True)

# Display or save the final concatenated DataFrame
final_dataframe.head()
# final_dataframe.to_csv("path_to_save_final_csv.csv", index=False)
# Out:
# Aug_request_Data_1.csv
# Aug_request_Data_10.csv
# Aug_request_Data_2.csv
# Aug_request_Data_3.csv
# Aug_request_Data_4.csv
# Aug_request_Data_5.csv
# Aug_request_Data_6.csv
# Aug_request_Data_7.csv
# Aug_request_Data_8.csv
# Aug_request_Data_9.csv
#    Unnamed: 0  Consumer_No Installation_Number Meter_Number Utility_ID Area  \
# 0           0    101886894          5002820974     00085410       SBPD    R
# 1           1    101886894          5002820974     00085410       SBPD    R
# 2           2    100000697          5000000696      1033471       SBPD    R
# 3           3    401834837          5003235247     15208951       NBPD    R
# 4           4    401834837          5003235247     15208951       NBPD    R
#
#   Division_ID Sub_Division_ID       MRU  Phase    Category  \
# 0         ABE            ABEC  ABEC66BI    3.0  NDS-IID(B)
# 1         ABE            ABEC  ABEC66BI    3.0  NDS-IID(B)
# 2         BAA            BAAB  BAAB7038    1.0      DS-IID
# ...

# %%
final_dataframe = final_dataframe.drop('Unnamed: 0', axis=1)

# %%
final_dataframe.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\BILLING_REQUEST_AND_REPLY\Billing_request\output_request\AUG_DATA_NEW\final_Data_request.csv")

# %%
data_1 = pd.read_csv(r"C:\Users\Ratan Kumar Jha\Desktop\BILLING_REQUEST_AND_REPLY\Reply\output_reply\AUG_NEW_DATA\AUG_REPLY_DATA_1.CSV")
data_1.head()
# Out:
#    Unnamed: 0  File_name  Consumer_ID Meter_Number Installation_Number  \
# 0           0   20240821    101861007    GL8548285          5002816030
# 1           1   20240821    101861007    GL8548285          5002816030
# 2           2   20240821    108342445    GL8548287          5003656078
# 3           3   20240821    108342445    GL8548287          5003656078
# 4           4   20240821    108539769    GL8548288          5003786277
#
#   Area_Type  Max_Demand_KW  Max_Demand_KVA  Power_Fact  Import_KWH  ...  \
# 0         R          1.647           1.657        0.97      1651.0  ...
# 1         R          1.647           1.657        0.97      1651.0  ...
# 2         R          0.727           0.730        0.98       320.0  ...
# 3         R          0.727           0.730        0.98       320.0  ...
# 4         R          2.920           2.926        0.92      1560.0  ...
#
#    Export_KVAH  Net_Metering  TOD   Read_Date Meter_Note       MRU  \
# ...

# %% [markdown]
# # for billing reply data

# %%
import pandas as pd
import os

new_Dataframe = []

path = r"C:\Users\Ratan Kumar Jha\Desktop\BILLING_REQUEST_AND_REPLY\Reply\output_reply\SEPT REPLY"
for file in os.listdir(path):
    print(file)
    if file.endswith(".csv"):
        new_file_path = os.path.join(path,file)
        data = pd.read_csv(new_file_path)
        
        new_Dataframe.append(data)

    
# Concatenate all the DataFrames in the list into a single DataFrame
final_dataframe = pd.concat(new_Dataframe, ignore_index=True)

# Display or save the final concatenated DataFrame
final_dataframe.head()
# final_dataframe.to_csv("path_to_save_final_csv.csv", index=False)
# Out:
# SEP_REPLY_DATA_1.CSV
# SEP_REPLY_DATA_10.CSV
# SEP_REPLY_DATA_11.CSV
# SEP_REPLY_DATA_12.CSV
# SEP_REPLY_DATA_13.CSV
# SEP_REPLY_DATA_14.CSV
# SEP_REPLY_DATA_15.CSV
# SEP_REPLY_DATA_16.CSV
# SEP_REPLY_DATA_17.CSV
# SEP_REPLY_DATA_18.CSV
# SEP_REPLY_DATA_19.CSV
# SEP_REPLY_DATA_2.CSV
# SEP_REPLY_DATA_3.CSV
# SEP_REPLY_DATA_4.CSV
# SEP_REPLY_DATA_5.CSV
# SEP_REPLY_DATA_6.CSV
# SEP_REPLY_DATA_7.CSV
# SEP_REPLY_DATA_8.CSV
# SEP_REPLY_DATA_9.CSV
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 17
#      13         new_Dataframe.append(data)
#      16 # Concatenate all the DataFrames in the list into a single DataFrame
# ---> 17 final_dataframe = pd.concat(new_Dataframe, ignore_index=True)
#      19 # Display or save the final concatenated DataFrame
#      20 final_dataframe.head()
#
# ...
